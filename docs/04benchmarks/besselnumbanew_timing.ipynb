# %%
from ttim.besselnumba import (
    besselld_gauss_ho_d1d2,
    besselld_gauss_ho_qxqy_d1d2,
    besselld_int_ho,
    besselld_int_ho_qxqy,
    bessells_gauss_ho_d1d2,
    bessells_gauss_ho_qxqy_d1d2,
    bessells_int_ho,
    bessells_int_ho_qxqy,
)
from ttim.besselnumbanew import (
    besselld_int_ho_new,
    besselld_int_ho_qxqy_new,
    bessells_int_ho_new,
    bessells_int_ho_qxqy_new,
)

# %%
# test data
x = 2
y = 3
d = 0.0001
z1 = -1 - 2j
z2 = 2 + 1j
d1 = -0.5
d2 = 0.2
lab1 = 8.0
order1 = 7
lab2 = 8 + 3j
order2 = 3

# %%
lab = lab1
order = order1

# %%
# these need to be called otherwise ruff complains that they are not used
potnew = bessells_int_ho_new(x, y, z1, z2, lab, order, d1, d2)
potold = bessells_int_ho(x, y, z1, z2, lab, order, d1, d2)
potgauss = bessells_gauss_ho_d1d2(x, y, z1, z2, lab, order, d1, d2)
#
qxqynew = bessells_int_ho_qxqy_new(x, y, z1, z2, lab, order, d1, d2)
qxqyold = bessells_int_ho_qxqy(x, y, z1, z2, lab, order, d1, d2)
qxqygauss = bessells_gauss_ho_qxqy_d1d2(x, y, z1, z2, lab, order, d1, d2)
#
potnew = besselld_int_ho_new(x, y, z1, z2, lab, order, d1, d2)
potold = besselld_int_ho(x, y, z1, z2, lab, order, d1, d2)
potgauss = besselld_gauss_ho_d1d2(x, y, z1, z2, lab, order, d1, d2)
#
qxqynew = besselld_int_ho_qxqy_new(x, y, z1, z2, lab, order, d1, d2)
qxqyold = besselld_int_ho_qxqy(x, y, z1, z2, lab, order, d1, d2)
qxqygauss = besselld_gauss_ho_qxqy_d1d2(x, y, z1, z2, lab, order, d1, d2)

# %% [markdown]
# ### Discharge potential line-sink

# %%
lab = lab1
order = order1

# %%
# %timeit potnew = bessells_int_ho_new(x, y, z1, z2, lab, order, d1, d2)
# Out:
# 9.15 μs ± 203 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %timeit potold = bessells_int_ho(x, y, z1, z2, lab, order, d1, d2)
# Out:
# 18.8 μs ± 414 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %timeit potgauss = bessells_gauss_ho_d1d2(x, y, z1, z2, lab, order, d1, d2)
# Out:
# 712 ns ± 10.4 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
lab = lab2
order = order2

# %%
# %timeit potnew = bessells_int_ho_new(x, y, z1, z2, lab, order, d1, d2)
# Out:
# 4.75 μs ± 39.9 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %timeit potold = bessells_int_ho(x, y, z1, z2, lab, order, d1, d2)
# Out:
# 9.66 μs ± 151 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %timeit potgauss = bessells_gauss_ho_d1d2(x, y, z1, z2, lab, order, d1, d2)
# Out:
# 761 ns ± 3.03 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Discharge vector line-sink

# %%
lab = lab1
order = order1

# %%
# %timeit qxqynew = bessells_int_ho_qxqy_new(x, y, z1, z2, lab, order, d1, d2)
# Out:
# 10.7 μs ± 9.5 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %timeit qxqyold = bessells_int_ho_qxqy(x, y, z1, z2, lab, order, d1, d2)
# Out:
# 22.3 μs ± 10.6 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %timeit qxqygauss = bessells_gauss_ho_qxqy_d1d2(x, y, z1, z2, lab, order, d1, d2)
# Out:
# 1.51 μs ± 20.8 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Discharge potential line-doublet

# %%
lab = lab1
order = order1

# %%
timeit potnew = besselld_int_ho_new(x, y, z1, z2, lab, order, d1, d2)
# Out:
# 9.89 μs ± 6.91 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
timeit potold = besselld_int_ho(x, y, z1, z2, lab, order, d1, d2)
# Out:
# 18.9 μs ± 337 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
timeit besselld_gauss_ho_d1d2(x, y, z1, z2, lab, order, d1, d2)
# Out:
# 591 ns ± 2.96 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Discharge vector line-doublet

# %%
lab = lab1
order = order1

# %%
timeit qxqynew = besselld_int_ho_qxqy_new(x, y, z1, z2, lab, order, d1, d2)
# Out:
# 20 μs ± 451 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
timeit qxqyold = besselld_int_ho_qxqy(x, y, z1, z2, lab, order, d1, d2)
# Out:
# 40.4 μs ± 28.2 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
timeit qxqygauss = besselld_gauss_ho_qxqy_d1d2(x, y, z1, z2, lab, order, d1, d2)
# Out:
# 1.48 μs ± 5.69 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
